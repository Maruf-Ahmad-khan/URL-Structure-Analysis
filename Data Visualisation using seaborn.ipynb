# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\mk744\OneDrive - Poornima University\Desktop\URL Structure Analysis\Data_EDA.csv")
df.shape
# Out:
# (569, 33)

# %%
df.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  'Unnamed: 32']

# %%
# y include our labels and x include our features 
y= df.diagnosis      # M or B
list = ['Unnamed: 32', 'id', 'diagnosis']
x = df.drop(list, axis = 1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
plt.figure(figsize=(6, 3))
print(df['diagnosis'].value_counts())
sns.set(style="darkgrid")
x = sns.countplot(x='diagnosis', data=df)
plt.title('Count of diagnosis')
plt.xticks(rotation=70)
plt.xlabel('diagnosis')
plt.show()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(6,3))
sns.relplot(data = df , x = 'radius_mean', y = 'texture_mean', hue="diagnosis")
plt.title("Scatter plot")
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# # Find the count of the days

# %%
def Count_Number_Days(tips):
     plt.figure(figsize=(6,3))
     sns.countplot(x = 'day', data = tips)
     plt.title("Count then number of Days")
     plt.show()
     
tips = sns.load_dataset("tips")
Count_Number_Days(tips)

# %% [markdown]
# # Find the count of time and smoker

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def Count_time(tips):
    plt.figure(figsize=(6,3))  # Correctly set the figure size
    sns.countplot(x='time', data=tips, hue='smoker')
    plt.title("Count of the Days")
    plt.show()

tips = sns.load_dataset("tips")
Count_time(tips)  # Correct way to call the function

# %%
def Count_Smokers(tips):
     plt.figure(figsize=(6,3))
     sns.countplot(x = 'smoker', data = tips)
     plt.title("Count of Smokers")
     plt.show()
     
tips = sns.load_dataset("tips")
Count_Smokers(tips)

# %% [markdown]
# # Count of Male and Female

# %%
def Gender_Count(tips):
     plt.figure(figsize=(6,3))
     sns.countplot(x = 'sex', data = tips)
     plt.title("Count of Gender")
     plt.show()
     
tips = sns.load_dataset("tips")
Gender_Count(tips)

# %% [markdown]
# # Establish the relationship using relplot between two numerical columns

# %%
def Scatter_Plot(tips):
     plt.figure(figsize=(6,3))
     sns.relplot(data = tips, x = "total_bill", y = 'tip', hue = "time")
     plt.title("Relationship between tips and bils columns")
     plt.show()


tips = sns.load_dataset("tips")
Scatter_Plot(tips)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def Scatter_Plot(tips):
    plt.figure(figsize=(6, 3))
    sns.scatterplot(data=tips, x="total_bill", y='tip')
    plt.title("Relationship between tips and total bill columns")
    plt.show()

tips = sns.load_dataset("tips")
Scatter_Plot(tips)

# %%
def Line_Plot(tips):
     plt.figure(figsize=(6,3))
     sns.relplot(data = tips, x = 'day', y = 'total_bill', kind='line', errorbar = None)
     plt.title("Line plot between day and total_bill")
     plt.show()
     
tips = sns.load_dataset('tips')
Line_Plot(tips)

# %%
def Line_Plot(tips):
     plt.figure(figsize=(6,3))
     sns.relplot(data = tips, x = 'day', y = 'total_bill', kind='line', estimator = None)
     plt.title("Line plot between day and total_bill")
     plt.show()
     
tips = sns.load_dataset('tips')
Line_Plot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(penguins, x="flipper_length_mm")
